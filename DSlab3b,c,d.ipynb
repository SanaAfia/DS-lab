# %% [markdown]
# <a href="https://colab.research.google.com/github/SanaAfia/DS-lab/blob/main/DSlab3b%2Cc%2Cd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({'gender':['Male','female','male']})
df['gender_name']= df['gender'].map({'male':0,'female':1})
df_renamed = df.rename(columns = {'gender_name':'gender'})
print(df_renamed)
# Out:
#    gender  gender
# 0    Male     NaN
# 1  female     1.0
# 2    male     0.0

# %%
import numpy as np
data = pd.DataFrame(np.random.randn(100,3))
outliers = (data>3)| (data<-3)
print(outliers.sum())
# Out:
# 0    1
# 1    1
# 2    2
# dtype: int64

# %%
import re
text = "This is\t a\n test"
split_text = re.split(r'\s+',text)
print(split_text)
# Out:
# ['This', 'is', 'a', 'test']
