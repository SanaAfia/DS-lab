# %% [markdown]
# <a href="https://colab.research.google.com/github/SanaAfia/DS-lab/blob/main/DSlab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"

df = pd.read_csv(url)

print("First five rows of the dataset:")
print(df.head())

print("\nDataset Information:")
df.info()

print("\nNumber of rows and columns:")
print(df.shape)
# Out:
# First five rows of the dataset:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"

df = pd.read_csv(url)

df.to_csv("iris_output.csv", index=False)

print("The dataset has been successfully written to iris_output.csv")
# Out:
# The dataset has been successfully written to iris_output.csv

# %%
import pandas as pd

data = """Roll-No\tName\tDepartment\tPercentage
101\tSana\tDS\t95
102\tJhansi\tDS\t92
103\tPravalika\tCSE\t88
104\tHarthi\tECE\t85"""

with open("students.txt", "w") as f:
    f.write(data)

df = pd.read_csv("students.txt", sep="\t")
print("Student data:")
print(df)

df = pd.read_table("students.txt")
print(df)
# Out:
# Student data:
#    Roll-No       Name Department  Percentage
# 0      101       Sana         DS          95
# 1      102     Jhansi         DS          92
# 2      103  Pravalika        CSE          88
# 3      104     Harthi        ECE          85
#    Roll-No       Name Department  Percentage
# 0      101       Sana         DS          95
# 1      102     Jhansi         DS          92
# 2      103  Pravalika        CSE          88
# 3      104     Harthi        ECE          85

# %%
import pandas as pd
student_data ={
    "roll_no": [101, 102, 103, 104],
    "name": ["Sana", "Jhansi", "Pravalika", "Harthi"],
    "department": ["DS", "DS", "CSE", "ECE"],
    "percentage":[95,92,88,85]
}
df = pd.DataFrame(student_data)
df.to_csv("students.csv", index=False)
print("The dataset has been successfully written to students.csv")
# Out:
# The dataset has been successfully written to students.csv
